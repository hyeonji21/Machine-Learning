# %%
import pandas as pd
df = pd.read_csv("C:/Users/0105l/Desktop/고려대학교/대학교/3학년 1학기/통계적머신러닝 PBL/팀프로젝트/data/train.csv")

# %%
df
# Out:
#        index gender car reality  child_num  income_total  \
# 0          0      F   N       N          0      202500.0
# 1          1      F   N       Y          1      247500.0
# 2          2      M   Y       Y          0      450000.0
# 3          3      F   N       Y          0      202500.0
# 4          4      F   Y       Y          0      157500.0
# ...      ...    ...  ..     ...        ...           ...
# 26452  26452      F   N       N          2      225000.0
# 26453  26453      F   N       Y          1      180000.0
# 26454  26454      F   Y       N          0      292500.0
# 26455  26455      M   N       Y          0      171000.0
# 26456  26456      F   N       N          0       81000.0
#
#                 income_type                       edu_type  \
# 0      Commercial associate               Higher education
# 1      Commercial associate  Secondary / secondary special
# 2                   Working               Higher education
# ...

# %%
df = df.drop('index', axis=1)
df
# Out:
#       gender car reality  child_num  income_total           income_type  \
# 0          F   N       N          0      202500.0  Commercial associate
# 1          F   N       Y          1      247500.0  Commercial associate
# 2          M   Y       Y          0      450000.0               Working
# 3          F   N       Y          0      202500.0  Commercial associate
# 4          F   Y       Y          0      157500.0         State servant
# ...      ...  ..     ...        ...           ...                   ...
# 26452      F   N       N          2      225000.0         State servant
# 26453      F   N       Y          1      180000.0               Working
# 26454      F   Y       N          0      292500.0               Working
# 26455      M   N       Y          0      171000.0               Working
# 26456      F   N       N          0       81000.0               Working
#
#                             edu_type           family_type  \
# ...

# %%
df.dtypes
# Out:
# gender            object
# car               object
# reality           object
# child_num          int64
# income_total     float64
# income_type       object
# edu_type          object
# family_type       object
# house_type        object
# DAYS_BIRTH         int64
# DAYS_EMPLOYED      int64
# FLAG_MOBIL         int64
# work_phone         int64
# phone              int64
# email              int64
# occyp_type        object
# family_size      float64
# begin_month      float64
# credit           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
# ...

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# gender            0.000000
# car               0.000000
# reality           0.000000
# child_num         0.000000
# income_total      0.000000
# income_type       0.000000
# edu_type          0.000000
# family_type       0.000000
# house_type        0.000000
# DAYS_BIRTH        0.000000
# DAYS_EMPLOYED     0.000000
# FLAG_MOBIL        0.000000
# work_phone        0.000000
# phone             0.000000
# email             0.000000
# occyp_type       30.884076
# family_size       0.000000
# begin_month       0.000000
# credit            0.000000
# dtype: float64

# %%
df = df.drop('occyp_type', axis=1)
df
# Out:
#       gender car reality  child_num  income_total           income_type  \
# 0          F   N       N          0      202500.0  Commercial associate
# 1          F   N       Y          1      247500.0  Commercial associate
# 2          M   Y       Y          0      450000.0               Working
# 3          F   N       Y          0      202500.0  Commercial associate
# 4          F   Y       Y          0      157500.0         State servant
# ...      ...  ..     ...        ...           ...                   ...
# 26452      F   N       N          2      225000.0         State servant
# 26453      F   N       Y          1      180000.0               Working
# 26454      F   Y       N          0      292500.0               Working
# 26455      M   N       Y          0      171000.0               Working
# 26456      F   N       N          0       81000.0               Working
#
#                             edu_type           family_type  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
classle = LabelEncoder()

df['gender_code'] = classle.fit_transform(df['gender'].values)
df['car_code'] = classle.fit_transform(df['car'].values)
df['reality_code'] = classle.fit_transform(df['reality'].values)
df['phone_code'] = classle.fit_transform(df['phone'].values)
df['email_code'] = classle.fit_transform(df['email'].values)
df['work_phone_code'] = classle.fit_transform(df['work_phone'].values)

df['income_type_code'] = classle.fit_transform(df['income_type'].values)
df['edu_type_code'] = classle.fit_transform(df['edu_type'].values)
df['family_type_code'] = classle.fit_transform(df['family_type'].values)
df['house_type_code'] = classle.fit_transform(df['house_type'].values)
df['income_total_code'] = classle.fit_transform(df['income_total'].values)

df
# Out:
#       gender car reality  child_num  income_total           income_type  \
# 0          F   N       N          0      202500.0  Commercial associate
# 1          F   N       Y          1      247500.0  Commercial associate
# 2          M   Y       Y          0      450000.0               Working
# 3          F   N       Y          0      202500.0  Commercial associate
# 4          F   Y       Y          0      157500.0         State servant
# ...      ...  ..     ...        ...           ...                   ...
# 26452      F   N       N          2      225000.0         State servant
# 26453      F   N       Y          1      180000.0               Working
# 26454      F   Y       N          0      292500.0               Working
# 26455      M   N       Y          0      171000.0               Working
# 26456      F   N       N          0       81000.0               Working
#
#                             edu_type           family_type  \
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             26457 non-null  object
#  1   car                26457 non-null  object
#  2   reality            26457 non-null  object
#  3   child_num          26457 non-null  int64
#  4   income_total       26457 non-null  float64
#  5   income_type        26457 non-null  object
#  6   edu_type           26457 non-null  object
#  7   family_type        26457 non-null  object
#  8   house_type         26457 non-null  object
#  9   DAYS_BIRTH         26457 non-null  int64
#  10  DAYS_EMPLOYED      26457 non-null  int64
#  11  FLAG_MOBIL         26457 non-null  int64
#  12  work_phone         26457 non-null  int64
#  13  phone              26457 non-null  int64
#  14  email              26457 non-null  int64
#  15  family_size        26457 non-null  float64
# ...

# %%
df_new = df

# %%
df_new = df_new.drop('gender', axis=1)
df_new = df_new.drop('car', axis=1)
df_new = df_new.drop('reality', axis=1)
df_new = df_new.drop('phone', axis=1)
df_new = df_new.drop('email', axis=1)
df_new = df_new.drop('work_phone', axis=1)
df_new = df_new.drop('income_type', axis=1)
df_new = df_new.drop('edu_type', axis=1)
df_new = df_new.drop('family_type', axis=1)
df_new = df_new.drop('house_type', axis=1)
df_new = df_new.drop('income_total', axis=1)
df_new = df_new.drop('FLAG_MOBIL', axis=1)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   child_num          26457 non-null  int64
#  1   DAYS_BIRTH         26457 non-null  int64
#  2   DAYS_EMPLOYED      26457 non-null  int64
#  3   family_size        26457 non-null  float64
#  4   begin_month        26457 non-null  float64
#  5   credit             26457 non-null  float64
#  6   gender_code        26457 non-null  int32
#  7   car_code           26457 non-null  int32
#  8   reality_code       26457 non-null  int32
#  9   phone_code         26457 non-null  int64
#  10  email_code         26457 non-null  int64
#  11  work_phone_code    26457 non-null  int64
#  12  income_type_code   26457 non-null  int32
#  13  edu_type_code      26457 non-null  int32
#  14  family_type_code   26457 non-null  int32
#  15  house_type_code    26457 non-null  int32
# ...

# %%
df_new.to_csv('C:/Users/0105l/Desktop/고려대학교/대학교/3학년 1학기/통계적머신러닝 PBL\팀프로젝트/df_new.csv',index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


data = df_new.corr()
fig, ax = plt.subplots( figsize=(13,13) )

mask = np.zeros_like(data, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(data, 
            cmap = 'RdYlBu_r', 
            annot = True,   
            mask=mask,     
            linewidths=.5,  
            cbar_kws={"shrink": .5},
            vmin = -1,vmax = 1  
           )  
plt.show()


from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
# Out:
# C:\Users\0105l\AppData\Local\Temp/ipykernel_10128/4126210916.py:9: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(data, dtype=np.bool)

# %%
# 상관분석

# %%
df['FLAG_MOBIL'].unique()
# Out:
# array([1], dtype=int64)

# %%
df = df.drop('FLAG_MOBIL', axis=1)

# %%
df['child_num'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['child_num'].value_counts()
# Out:
# 0     18340
# 1      5386
# 2      2362
# 3       306
# 4        47
# 5        10
# 14        3
# 7         2
# 19        1
# Name: child_num, dtype: int64

# %%
df
# Out:
#       gender car reality  child_num income_total           income_type  \
# 0          F   N       N          0          소득0  Commercial associate
# 1          F   N       Y          1          소득0  Commercial associate
# 2          M   Y       Y          0          소득1               Working
# 3          F   N       Y          0          소득0  Commercial associate
# 4          F   Y       Y          0          소득0         State servant
# ...      ...  ..     ...        ...          ...                   ...
# 26452      F   N       N          2          소득0         State servant
# 26453      F   N       Y          1          소득0               Working
# 26454      F   Y       N          0          소득1               Working
# 26455      M   N       Y          0          소득0               Working
# 26456      F   N       N          0          소득0               Working
#
#                             edu_type           family_type  \
# ...

# %%
## EDA 시각화

# %%
# 연간 소득(income_total) 데이터 시각화

sns.boxplot(data=df,y="income_total", width=0.3, color='tab:blue')
plt.title('Annual income distribution')
plt.ylim(2000, 600000)
plt.show()

# %%
# 성별 간 연간 소득 (income_total)

green = dict(markerfacecolor='g', marker='s')
sns.boxplot(data=df,y="income_total",x='gender', width=0.3,flierprops=green)
plt.title('Annual income distribution by gender')
plt.ylim(2000, 600000)
plt.show()

# %%
# 나이(DAYS_BIRTH) 변환 작업
import numpy as np
df['new_age'] = round(abs(df['DAYS_BIRTH'])/365.5,0).astype(np.int32)
df.head(2)
# Out:
#    index gender car reality  child_num  income_total           income_type  \
# 0      0      F   N       N          0      202500.0  Commercial associate
# 1      1      F   N       Y          1      247500.0  Commercial associate
#
#                         edu_type     family_type           house_type  ...  \
# 0               Higher education         Married  Municipal apartment  ...
# 1  Secondary / secondary special  Civil marriage    House / apartment  ...
#
#    DAYS_EMPLOYED  FLAG_MOBIL  work_phone  phone  email  occyp_type  \
# 0          -4709           1           0      0      0         NaN
# 1          -1540           1           0      0      1    Laborers
#
#   family_size  begin_month  credit  new_age
# 0         2.0         -6.0     1.0       38
# 1         3.0         -5.0     1.0       31
#
# [2 rows x 21 columns]

# %%
df['new_age'].plot.hist(bins=range(10,81,10), edgecolor='k')
plt.xlabel('age')
plt.title('Age distribution')
plt.show()

# %%
# 성별에 따른 분포
sex = df.groupby('gender')
M_group= sex.get_group('M')
F_group= sex.get_group('F')
M = M_group['new_age']
F = F_group['new_age']

plt.hist([M,F], bins=range(10,81,10), label=['Male', 'Female'],edgecolor='k')
plt.legend(loc='upper left')
plt.title('Age distribution by gender')
plt.show()

# %%
# 신용카드 발급 월(begin_month) 데이터 시각화

df['new_begin_month'] = [0 if s >=0 else round(abs(s)/12,2) for s in df['begin_month']]
sns.displot(data=df,x='new_begin_month',kind='kde')
title_color = 'black'
plt.title('Average Credit Card Issuance Date',color=title_color)
plt.show()

# %%
it = df.groupby('income_type').count()['index']
it
# Out:
# income_type
# Commercial associate     6202
# Pensioner                4449
# State servant            2154
# Student                     7
# Working                 13645
# Name: index, dtype: int64

# %%
explode = (0.1, 0.1, 0.1, 0.2, 0.0)
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'red']
plt.pie(it,explode=explode,colors=colors, labels=it.index, startangle=180,autopct='%1.1f%%',wedgeprops = {'edgecolor':'k','linestyle':'--','linewidth':1},textprops={'color':"black"})
title_color = 'black'
plt.title('Income type',color=title_color)
plt.show()

# %%
# 교육 수준(edu_type) 데이터 시각화

et = df.groupby('edu_type').count()['index']
et = et.reset_index()
et

sns.barplot(data=et, y="edu_type", x="index", orient='h',color='dodgerblue')
title_color = 'black'
plt.title('Education type',color=title_color)
plt.show()

# %%
# 총소득, 나이, 직장 경력에 따른 신용도 (?)

f,ax=plt.subplots(1,3,figsize=(25,8))
sns.violinplot("credit","income_total", data=df,split=True,ax=ax[0])
ax[0].set_title('credit and income_total')
#ax[0].set_yticks(range(0,110,10))
sns.violinplot("credit","DAYS_BIRTH",  data=df,split=True,ax=ax[1])
ax[1].set_title('Credit and days_birth')
#ax[1].set_yticks(range(0,110,10))
sns.violinplot("credit","DAYS_EMPLOYED", data=df,split=True,ax=ax[2])
ax[2].set_title('Credit and Days_employed')
#ax[1].set_yticks(range(0,110,10))
plt.show()
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   child_num          26457 non-null  int64
#  1   DAYS_BIRTH         26457 non-null  int64
#  2   DAYS_EMPLOYED      26457 non-null  int64
#  3   family_size        26457 non-null  float64
#  4   begin_month        26457 non-null  float64
#  5   credit             26457 non-null  float64
#  6   gender_code        26457 non-null  int32
#  7   car_code           26457 non-null  int32
#  8   reality_code       26457 non-null  int32
#  9   phone_code         26457 non-null  int64
#  10  email_code         26457 non-null  int64
#  11  work_phone_code    26457 non-null  int64
#  12  income_type_code   26457 non-null  int32
#  13  edu_type_code      26457 non-null  int32
#  14  family_type_code   26457 non-null  int32
#  15  house_type_code    26457 non-null  int32
# ...

# %%
import pandas as pd
df = pd.read_csv("C:/Users/0105l/Desktop/고려대학교/대학교/3학년 1학기/통계적머신러닝 PBL/팀프로젝트/data/df_new.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   child_num          26457 non-null  int64
#  1   DAYS_BIRTH         26457 non-null  int64
#  2   DAYS_EMPLOYED      26457 non-null  int64
#  3   family_size        26457 non-null  float64
#  4   begin_month        26457 non-null  float64
#  5   credit             26457 non-null  float64
#  6   gender_code        26457 non-null  int64
#  7   car_code           26457 non-null  int64
#  8   reality_code       26457 non-null  int64
#  9   phone_code         26457 non-null  int64
#  10  email_code         26457 non-null  int64
#  11  work_phone_code    26457 non-null  int64
#  12  income_type_code   26457 non-null  int64
#  13  edu_type_code      26457 non-null  int64
#  14  family_type_code   26457 non-null  int64
#  15  house_type_code    26457 non-null  int64
# ...

# %%
X = df.drop('credit', axis=1)

# %%
X = df.drop('DAYS_EMPLOYED', axis=1)

# %%
X = df.drop('family_size', axis=1)

# %%
X = df.drop('credit', axis=1)
y = df['credit']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
# knn

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=4, p=2)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
y_train_pred = knn.predict(X_train)
y_test_pred = knn.predict(X_test)

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_train, y_train_pred))
print(metrics.accuracy_score(y_test, y_test_pred))
# Out:
# 0.7613262055186565
# 0.6112370874275637

# %%
from sklearn.metrics import confusion_matrix
conf = confusion_matrix(y_true=y_test, y_pred=y_test_pred)
print(conf)
# Out:
# [[ 296  180  491]
#  [ 146  795  939]
#  [ 392  938 3761]]

# %%
[[ 258  171  538]
 [ 146  612 1122]
 [ 343  683 4065]]

# %%
from sklearn import tree
dtc = tree.DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=1)
result = dtc.fit(X_train, y_train)  
y_train_pred = dtc.predict(X_train) 
y_test_pred = dtc.predict(X_test)

# %%
#tree.plot_tree(dtc.fit(X_train, y_train))

# %%
print(metrics.accuracy_score(y_train, y_train_pred))
print(metrics.accuracy_score(y_test, y_test_pred))
# Out:
# 0.6932339759166262
# 0.6888384983623079

# %%
conf = confusion_matrix(y_true=y_test, y_pred=y_test_pred)
print(conf)
# Out:
# [[   0  119  848]
#  [   0  439 1441]
#  [   0   37 5054]]

# %%
conf = confusion_matrix(y_true=y_test, y_pred=y_test_pred)
print(conf)
# Out:
# [[   4  127  836]
#  [   9  439 1432]
#  [   8   67 5016]]

# %%
print(metrics.accuracy_score(y_train, y_train_pred))
print(metrics.accuracy_score(y_test, y_test_pred))
# Out:
# 0.6956099141422323
# 0.6877047115142353

# %%
target = pd.DataFrame(df_new.credit)
target.columns = ['target']

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   child_num          26457 non-null  int64
#  1   DAYS_BIRTH         26457 non-null  int64
#  2   DAYS_EMPLOYED      26457 non-null  int64
#  3   family_size        26457 non-null  float64
#  4   begin_month        26457 non-null  float64
#  5   credit             26457 non-null  float64
#  6   gender_code        26457 non-null  int32
#  7   car_code           26457 non-null  int32
#  8   reality_code       26457 non-null  int32
#  9   phone_code         26457 non-null  int64
#  10  email_code         26457 non-null  int64
#  11  work_phone_code    26457 non-null  int64
#  12  income_type_code   26457 non-null  int32
#  13  edu_type_code      26457 non-null  int32
#  14  family_type_code   26457 non-null  int32
#  15  house_type_code    26457 non-null  int32
# ...

# %%
columns = ['child_num', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'family_size', 'begin_month', 'gender_code', 'car_code', 'reality_code', 'phone_code', 
           'email_code', 'work_phone_code', 'income_type_code', 'edu_type_code', 'family_type_code', 'house_type_code', 'income_total_code']

# %%
target = ['credit']

# %%
df_new[columns]
# Out:
#        child_num  DAYS_BIRTH  DAYS_EMPLOYED  family_size  begin_month  \
# 0              0      -13899          -4709          2.0         -6.0
# 1              1      -11380          -1540          3.0         -5.0
# 2              0      -19087          -4434          2.0        -22.0
# 3              0      -15088          -2092          2.0        -37.0
# 4              0      -15037          -2105          2.0        -26.0
# ...          ...         ...            ...          ...          ...
# 26452          2      -12079          -1984          4.0         -2.0
# 26453          1      -15291          -2475          2.0        -47.0
# 26454          0      -10082          -2015          2.0        -25.0
# 26455          0      -10145           -107          1.0        -59.0
# 26456          0      -19569          -1013          2.0         -9.0
#
#        gender_code  car_code  reality_code  phone_code  email_code  \
# ...

# %%
# Graphic
from pydotplus import graph_from_dot_data
from sklearn.tree import export_graphviz
dot_data = export_graphviz(result, filled=True, rounded=True, class_names=df['credit'],
feature_names=df[columns], out_file=None)
graph = graph_from_dot_data(dot_data)
graph.write_png('tree1.png')  

from IPython.display import Image
Image(graph.create_png())  # Console 창에 결과 그림 출력
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10128/1639524525.py in <module>
#       2 from pydotplus import graph_from_dot_data
#       3 from sklearn.tree import export_graphviz
# ----> 4 dot_data = export_graphviz(result, filled=True, rounded=True, class_names=df_new['credit'],
#       5 feature_names=df_new[columns], out_file=None)
#       6 graph = graph_from_dot_data(dot_data)
#
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %%
# Accuracy score
from sklearn import metrics
print(metrics.accuracy_score(y_train, y_train_pred))
print(metrics.accuracy_score(y_test, y_test_pred))
# Out:
# 0.691074032075166
# 0.6919879062736206

# %%
import numpy as np
unique, counts = np.unique(y_test, return_counts=True)
np.asarray((unique, counts)).T
# Out:
# array([[0.000e+00, 9.670e+02],
#        [1.000e+00, 1.880e+03],
#        [2.000e+00, 5.091e+03]])

# %%
#Confusion matrix
print(metrics.confusion_matrix(y_test, y_test_pred))
# Out:
# [[   0  119  848]
#  [   0  439 1441]
#  [   0   37 5054]]

# %%
from sklearn import tree
dtc = tree.DecisionTreeClassifier(criterion='gini', max_depth=14, random_state=1)
result = dtc.fit(X_train, y_train)  # 적합
y_train_pred = dtc.predict(X_train) # Training accuracy
y_test_pred = dtc.predict(X_test)   # Test accuracy

# %%
# Accuracy score
from sklearn import metrics
print(metrics.accuracy_score(y_train, y_train_pred))
print(metrics.accuracy_score(y_test, y_test_pred))
# Out:
# 0.7403207516604569
# 0.6811539430587049

# %%
# KNN의 적용
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5, p=2)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_train_pred = knn.predict(X_train) # Training accuracy
y_test_pred = knn.predict(X_test)   # Test accuracy

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_train, y_train_pred))
print(metrics.accuracy_score(y_test, y_test_pred))
# Out:
# 0.743992656190939
# 0.6216931216931217

# %%
import numpy as np
unique, counts = np.unique(y_test, return_counts=True)
np.asarray((unique, counts)).T
# Out:
# array([[0.000e+00, 9.670e+02],
#        [1.000e+00, 1.880e+03],
#        [2.000e+00, 5.091e+03]])

# %%
print(metrics.confusion_matrix(y_test, y_test_pred))
# Out:
# [[ 258  171  538]
#  [ 146  612 1122]
#  [ 343  683 4065]]

# %%
from sklearn.linear_model import LogisticRegression
Logit = LogisticRegression(C=1e2, random_state=1, max_iter=200)
Logit.fit(X_train, y_train)
y_train_pred = Logit.predict(X_train)
y_test_pred = Logit.predict(X_test)

# %%
print(accuracy_score(y_test, y_test_pred))
print(accuracy_score(y_train, y_train_pred))

print(confusion_matrix(y_test, y_test_pred))
# Out:
# 0.6413454270597128
# 0.6413413251255468
# [[   0    0  967]
#  [   0    0 1880]
#  [   0    0 5091]]

# %%
import xgboost as xgb
xg_reg = xgb.XGBRegressor(objective='reg:squarederror', booster='gbtree', colsample_bytree=0.75, learning_rate = 0.1, max_depth=5, alpha=10,
                          n_estimators=30)

# %%
xg_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.75,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=5, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=30, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=10, ...)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_test_pred))
print(accuracy_score(y_train, y_train_pred))
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_test_pred))
# Out:
# 0.6877047115142353
# 0.6956099141422323
# [[   4  127  836]
#  [   9  439 1432]
#  [   8   67 5016]]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

pipe_lr = make_pipeline(StandardScaler(), PCA(n_components=4), LogisticRegression(random_state=1, solver='lbfgs'))
pipe_lr.fit(X_train, y_train)
y_train_pred = pipe_lr.predict(X_train)
y_test_pred = pipe_lr.predict(X_test)

# %%
print(pipe_lr.score(X_train, y_train))
print(pipe_lr.score(X_test, y_test))
# Out:
# 0.6413413251255468
# 0.6413454270597128

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(estimator=pipe_lr, X=X_train, y=y_train, cv=10)
print('CV accuracy scores: %s' % scores)

import numpy as np
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# CV accuracy scores: [0.64146868 0.64146868 0.64146868 0.64146868 0.64092873 0.64092873
#  0.64092873 0.64146868 0.64146868 0.64181524]
# CV accuracy: 0.641 +/- 0.000

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier
inner_cv = KFold(n_splits=3, shuffle=True, random_state=0)
outer_cv = KFold(n_splits=5, shuffle=True, random_state=0)
gs = GridSearchCV(estimator=DecisionTreeClassifier(random_state=0), 
                  param_grid=[{'max_depth': [1,2,3,4,5,6,7,None]}],
                  scoring='accuracy', cv=inner_cv)
scores = cross_val_score(gs, X, y, scoring='accuracy', cv=outer_cv)
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# CV accuracy: 0.691 +/- 0.005

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
inner_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=0)
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
gs = GridSearchCV(estimator=DecisionTreeClassifier(random_state=0), 
                  param_grid=[{'max_depth': [1,2,3,4,5,6,7,None]}],
                  scoring='accuracy', cv=inner_cv)
scores = cross_val_score(gs, X, y, scoring='accuracy', cv=outer_cv)
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# CV accuracy: 0.690 +/- 0.003

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
pipe_svc = make_pipeline(StandardScaler(), SVC(random_state=1))
inner_cv = KFold(n_splits=3, shuffle=True, random_state=0)
outer_cv = KFold(n_splits=5, shuffle=True, random_state=0)
gs = GridSearchCV(estimator=DecisionTreeClassifier(random_state=0), 
                  param_grid=[{'max_depth': [1,2,3,4,5,6,7,None]}],
                  scoring='accuracy', cv=inner_cv)
scores = cross_val_score(gs, X, y, scoring='accuracy', cv=outer_cv)
print('CV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
